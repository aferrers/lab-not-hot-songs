# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('tcc_ceds_music.csv')

# %%
data = data.drop(columns=['Unnamed: 0'])

# %%
data_sample = data.sample(3000)
data_sample
# Out:
#                 artist_name                           track_name  \
# 15188  kenny wayne shepherd             born with a broken heart
# 19336           count basic                          on the move
# 21364           steel pulse                       dub marcus say
# 10775        bruce cockburn                      pacing the cage
# 17243         nat king cole                              pretend
# ...                     ...                                  ...
# 21355         triston palma                          girl i love
# 21698               macka b                            peace cup
# 5415              anti-flag  this is the end (for you my friend)
# 10722          alan jackson                     tall, tall trees
# 24476         ozzy osbourne                         little dolls
#
#        release_date    genre  \
# 15188          1995    blues
# 19336          1996     jazz
# 21364          1982   reggae
# 10775          1996  country
# 17243          1954     jazz
# ...

# %%
#saving new dataframe to csv
data_sample.to_csv('not_hot_songs_sample_raw.csv', index=False)
